# %%
# %pip install selenium
# Out:
# Requirement already satisfied: selenium in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (4.38.0)
# Requirement already satisfied: urllib3<3.0,>=2.5.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from urllib3[socks]<3.0,>=2.5.0->selenium) (2.5.0)
# Requirement already satisfied: trio<1.0,>=0.31.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from selenium) (0.32.0)
# Requirement already satisfied: trio-websocket<1.0,>=0.12.2 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from selenium) (0.12.2)
# Requirement already satisfied: certifi>=2025.10.5 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from selenium) (2025.11.12)
# Requirement already satisfied: typing_extensions<5.0,>=4.15.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from selenium) (4.15.0)
# Requirement already satisfied: websocket-client<2.0,>=1.8.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from selenium) (1.9.0)
# Requirement already satisfied: attrs>=23.2.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from trio<1.0,>=0.31.0->selenium) (25.4.0)
# Requirement already satisfied: sortedcontainers in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from trio<1.0,>=0.31.0->selenium) (2.4.0)
# Requirement already satisfied: idna in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from trio<1.0,>=0.31.0->selenium) (3.11)
# Requirement already satisfied: outcome in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from trio<1.0,>=0.31.0->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from trio<1.0,>=0.31.0->selenium) (1.3.1)
# Requirement already satisfied: wsproto>=0.14 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from trio-websocket<1.0,>=0.12.2->selenium) (1.3.1)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from urllib3[socks]<3.0,>=2.5.0->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.16.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from wsproto>=0.14->trio-websocket<1.0,>=0.12.2->selenium) (0.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
# from webdriver_manager.chrome import ChromeDriverManager

# 建立 Service 物件，指定 chromedriver.exe 的路徑
service = Service('./chromedriver.exe')

# 設定 Chrome 瀏覽器的選項
options = webdriver.ChromeOptions()
options.add_argument("--start-maximized") # Chrome 瀏覽器在啟動時最大化視窗
options.add_argument("--incognito") # 無痕模式
options.add_argument("--disable-popup-blocking") # 停用 Chrome 的彈窗阻擋功能。

# 建立 Chrome 瀏覽器物件
driver = webdriver.Chrome(options=options)
driver.get("https://pstw.panasonic.com.tw/shop")
